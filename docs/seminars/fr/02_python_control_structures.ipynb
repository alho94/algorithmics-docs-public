# %% [markdown]
# # Séminaire 2 : Bases de Python I : Structures de contrôle
#
# ---
#
# :::{important} Traduction en cours
# Ce notebook n'a pas encore été traduit en français. Veuillez consulter la [version anglaise](../en/02_python_control_structures.ipynb) en attendant.
# :::
