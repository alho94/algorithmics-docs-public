# %% [markdown]
# # Séminaire 3 : Bases de Python II : Structures de données
#
# ---
#
# :::{important} Traduction en cours
# Ce notebook n'a pas encore été traduit en français. Veuillez consulter la [version anglaise](../en/03_python_data_structures.ipynb) en attendant.
# :::
